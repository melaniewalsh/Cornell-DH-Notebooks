# %% [markdown]
# # Mapping Kate Chopin's *The Awakening*

# %% [markdown]
# *This is an example of a data-driven essay that might be published in the Cornell DH Notebook Series. This is a Jupyter notebook file that can be downloaded as an .ipynb file and a PDF, and it can also be opened and [run in the cloud](https://mybinder.org/v2/gh/melaniewalsh/Cornell-DH-Notebooks/main?urlpath=lab/tree/jupyterbook/notebooks/Issue-1/Mapping-Kate-Chopin.ipynb).*

# %% [markdown]
# ## Introduction

# %% [markdown]
# *Essays will begin with an introduction*

# %% [markdown]
# In this essay, we will explore the geography of Kate Chopin's 1899 novel *The Awakening*. The novel is set in Louisiana, but it also discusses and imagines many other locations around the world.
#
# To explore this geography, we will use a natural language processing method called Named Entity Recognition (NER) to identify places mentioned in *The Awakening*. Then we will geocode these locations and map them.

# %% [markdown]
# ## Dataset

# %% [markdown]
# *Essays will describe the data*

# %% [markdown]
# ### Kate Chopin's *The Awakening*

# %% [markdown]
# ```{epigraph}
# Robert spoke of his intention to go to Mexico in the autumn, where fortune awaited him. He was always intending to go to Mexico, but some way never got there. Meanwhile he held on to his modest position in a mercantile house in
# New Orleans, where an equal familiarity with English, French and Spanish gave him no small value as a clerk and correspondent.
#
# -- Kate Chopin, *The Awakening*
# ```

# %% [markdown]
# :::{admonition,dropdown,tip} Jupyter Book Tip
# Jupyter Book allows you to include special "directives" for creating cool features on our published website. For example, we can create a dropdown tip like this one by using a [dropdown tip directive](https://jupyterbook.org/content/content-blocks.html#hiding-the-content-of-admonitions) or we can create an epigraph like the one above by using an [epigraph directive](https://jupyterbook.org/content/content-blocks.html#quotations-and-epigraphs).
# :::

# %% [markdown]
# ## Computational Narrative/Argument

# %% [markdown]
# *Essays will proceed to make an argument or construct a narrative interspersed with code and explanations. Because this example is drawn from my course materials, it is heavy on the code/explanation and light on the narrative/argument, but ideally it would contain more claims, insights, findings, etc.*

# %% [markdown]
# ## Named Entity Recognition

# %% [markdown]
# ## Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# We import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %% [markdown]
# We also import the `Counter` module for counting places and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ### Download Language Model

# %% [markdown]
# Next we download the English-language model (`en_core_web_sm`), which will be processing and making predictions about our texts.

# %%
# !python -m spacy download en_core_web_sm

# %% [markdown]
# :::{note}
# spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including German, French, Spanish, Portuguese, Italian, Dutch, Greek, Norwegian, and Lithuanian. Languages such as Russian, Ukrainian, Thai, Chinese, Japanese, Korean and Vietnamese don't currently have their own NLP models. However, spaCy offers language and tokenization support for many of these language with external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean or [Jieba](https://github.com/fxsjy/jieba) for Chinese.
# :::

# %% [markdown]
# ### Load Language Model

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %% [markdown]
# ## Process Document

# %% [markdown]
# In the cell below, we open and read *The Awakening*. Then we process our `document` with the loaded NLP model. Most of the heavy NLP lifting is done in this line of code.

# %%
filepath = "../../data/The-Awakening-Kate-Chopin.txt"
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## spaCy Named Entities

# %% [markdown]
# To quickly see spaCy's NER in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) with the `style=` parameter set to "ent"  (short for entities):

# %%
displacy.render(document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ﻿Project Gutenberg's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Awakening and Selected Short Stories
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# , by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kate Chopin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br>This eBook is for the use of anyone anywhere at no cost and with</br>almost no restrictions whatsoever.  You may copy it, give it away or</br>re-use it under the terms of the Project
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gutenberg License
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  included</br>with this
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  or online at www.gutenberg.org</br></br></br>Title: The Awakening and Selected Short Stories</br></br>Author:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kate Chopin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br>Release Date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 11, 2006
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  [EBook #
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     160
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ]</br>Last Updated:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 15, 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br></br>Language:
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     English
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# </br></br>Character set encoding:
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UTF-8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br></br>*** START OF THIS PROJECT GUTENBERG EBOOK THE AWAKENING AND SELECTED ***</br></br></br></br></br>Produced by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Judith Boss
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Widger
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br></br></br></br></br>THE AWAKENING</br></br>AND SELECTED SHORT STORIES</br></br>by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kate Chopin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br></br>With an Introduction by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marilynne Robinson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br></br></br></br></br>Contents:</br></br>     The Awakening</br>     Beyond The Bayou</br>     Ma'ame Pelagie</br>     Desiree's Baby</br>     A Respectable Woman</br>     The Kiss</br>     A Pair Of Silk Stockings</br>     The Locket</br>     A Reflection</br></br></br></br></br></br>THE AWAKENING</br></br></br></br></br>I</br></br></br>A green and yellow parrot, which hung in a cage outside the door, kept</br>repeating over and over:</br></br>“Allez vous-en! Allez vous-en! Sapristi! That's all right!”</br></br>He could speak a little
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# , and also a language which nobody</br>understood, unless it was the mocking-bird that hung on the other</br>side of the door, whistling his fluty notes out upon the breeze with</br>maddening persistence.</br></br>Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pontellier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , unable to read his newspaper with any degree of comfort,</br>arose with an expression and an exclamation of disgust.</br></br>He walked down the gallery and across the narrow “bridges” which</br>connected the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lebrun
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  cottages one with the other. He had been seated</br>before the door of the main house. The parrot and the mocking-bird were</br>the property of
# <mark class="entity" style="background: #aa9cfc

# %% [markdown]
# :::{admonition,dropdown,tip} Jupyter Book Tip
# You can hide cells, hide outputs, or choose to make an output scrollable by adding the [correct directives](https://jupyterbook.org/interactive/hiding.html?highlight=hide#the-toggle-directive) or [metadata tags](https://jupyterbook.org/content/layout.html?highlight=output_scroll#scrolling-cell-outputs) to Jupyter cells. Read more about [How to Add Metadata Tags to Jupyter Notebook Cells](https://jupyterbook.org/advanced/advanced.html#how-should-i-add-cell-tags-and-metadata-to-my-notebooks)
# :::

# %% [markdown]
# ### Get Places

# %% [markdown]
# All the named entities in our document can be found in the `document.ents` property. Each of the named entities in `document.ents` contains more [information about itself](https://spacy.io/usage/linguistic-features#accessing), which we can access by iterating through them with a simple for loop.
#
# For each named_entity, we will only extract the named_entity if the corresponding named_entity.label_ is "GPE."  This is the type label for "counties cities, states."

# %%
places = []

for named_entity in document.ents:
    if named_entity.label_ == "GPE":
        places.append(named_entity.text)

places_tally = Counter(places)

places_df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
places_df
# Out:
#                  place  count
# 0               Mexico     19
# 1          New Orleans     11
# 2             Kentucky      7
# 3    the United States      7
# 4             New York      6
# 5             Valmonde      6
# 6             Brantain      6
# 7          Mississippi      5
# 8              Leandre      5
# 9            Iberville      4
# 10                Edna      4
# 11               Paris      4
# 12          Gouvernail      4
# 13           Louisiana      4
# 14              Armand      4
# 15           Beaudelet      3
# 16               Tonie      3
# 17          Grand Isle      3
# 18           Gutenberg      3
# 19                U.S.      3
# 20            Laidpore      2
# 21  the City of Mexico      2
# 22           Impromptu      2
# 23              Celina      2
# 24              L'Abri      2
# 25               UTF-8      1
# 26          Carondelet      1
# 27              Eskimo      1
# 28   Edna Pontellier's      1
# 29              Biloxi      1
# 30           Angostura      1
# 31              Empire      1
# 32             Lourdes      1
# 33             Acadian      1
# 34        New\nOrleans      1
# 35           Carrolton      1
# 36                City      1
# 37             Gruyere      1
# 38          candelabra      1
# 39              Geneva      1
# 40              Victor      1
# 41             bandana      1
# 42              Arobin      1
# 43            Mandelet      1
# 44          Mariequita      1
# 45             America      1
# 46              Leonce      1
# 47             spendor      1
# 48               Venus      1
# 49              France      1
# 50            Zandrine      1
# 51               Janie      1
# 52                 Mag      1
# 53       United States      1
# 54           GUTENBERG      1
# 55              DIRECT      1
# 56            INDIRECT      1
# 57      Salt Lake City      1

# %% [markdown]
# ## Geocoding

# %% [markdown]
# First, we're going to geocode data — aka get coordinates from addresses or place names — with the Python package [GeoPy](https://geopy.readthedocs.io/en/stable/#). GeoPy makes it easier to use a range of third-party [geocoding API services](https://geopy.readthedocs.io/en/stable/#), such as Google, Bing, ArcGIS, and OpenStreetMap.
#
# Though most of these services require an API key, Nominatim, which uses OpenStreetMap data, does not, which is why we're going to use it here.

# %% [markdown]
# ### Install GeoPy

# %%
# !pip install geopy

# %% [markdown]
# ### Import Nominatim

# %% [markdown]
# From GeoPy's list of possible geocoding services, we're going to import Nominatim:

# %%
from geopy.geocoders import Nominatim

# %% [markdown]
# Nominatim (which means "name" in Latin) uses [OpenStreetMap data](https://www.openstreetmap.org/relation/174979) to match addresses with geopgraphic coordinates. Though we don't need an API key to use Nominatim, we do need to create a unique [application name](https://operations.osmfoundation.org/policies/nominatim/).

# %% [markdown]
# Here we're initializing Nominatim as a variable called `geolocator`. You can make the application name ("Our mapping app") anything you want.

# %%
geolocator = Nominatim(user_agent="Our mapping app", timeout=2)

# %% [markdown]
# To geocode an address or location, we simply use the `.geocode()` function:

# %%
location = geolocator.geocode("New Orleans")
location
# Out:
# Location(New Orleans, Orleans Parish, Louisiana, United States of America, (29.9499323, -90.0701156, 0.0))

# %% [markdown]
# ## Geocode with Pandas

# %% [markdown]
# To geocode every location in a CSV file, we can use Pandas, make a Python function, and `.apply()` it to every row in the CSV file.

# %% [markdown]
# Here we make a function with `geolocator.geocode()` and ask it to return the address, lat/lon, and importance score:

# %%
def find_location(row):
    
    place = row['place']
    
    location = geolocator.geocode(place)
    
    if location != None:
        return location.address, location.latitude, location.longitude, location.raw['importance']
    else:
        return "Not Found", "Not Found", "Not Found", "Not Found"

# %% [markdown]
# Now let's `.apply()` our function to this Pandas dataframe and see what results Nominatim's geocoding service spits out.

# %%
places_df[['address', 'lat', 'lon', 'importance']] = places_df.apply(find_location, axis="columns", result_type="expand")
places_df
# Out:
#                  place  count  \
# 0               Mexico     19
# 1          New Orleans     11
# 2             Kentucky      7
# 3    the United States      7
# 4             New York      6
# 5             Valmonde      6
# 6             Brantain      6
# 7          Mississippi      5
# 8              Leandre      5
# 9            Iberville      4
# 10                Edna      4
# 11               Paris      4
# 12          Gouvernail      4
# 13           Louisiana      4
# 14              Armand      4
# 15           Beaudelet      3
# 16               Tonie      3
# 17          Grand Isle      3
# 18           Gutenberg      3
# 19                U.S.      3
# 20            Laidpore      2
# 21  the City of Mexico      2
# 22           Impromptu      2
# 23              Celina      2
# 24              L'Abri      2
# 25               UTF-8      1
# 26          Carondelet      1
# 27              Eskimo      1
# 28   Edna Pontellier's      1
# 29              Biloxi      1
# 30           Angostura      1
# 31              Empire      1
# 32             Lourdes      1
# 33             Acadian      1
# 34        New\nOrleans      1
# 35           Carrolton      1
# 36                City      1
# 37             Gruyere      1
# 38          candelabra      1
# 39              Geneva      1
# 40              Victor      1
# 41             bandana      1
# 42              Arobin      1
# 43            Mandelet      1
# 44          Mariequita      1
# 45             America      1
# 46              Leonce      1
# 47             spendor      1
# 48               Venus      1
# 49              France      1
# 50            Zandrine      1
# 51               Janie      1
# 52                 Mag      1
# 53       United States      1
# 54           GUTENBERG      1
# 55              DIRECT      1
# 56            INDIRECT      1
# 57      Salt Lake City      1
#
#                                                                                                                                                      address  \
# 0                                                                                                                                                     México
# 1                                                                                           New Orleans, Orleans Parish, Louisiana, United States of America
# 2                                                                                                                         Kentucky, United States of America
# 3                                                                                                                                              United States
# 4                                                                                                                         New York, United States of America
# 5                                                                                                                                                  Not Found
# 6                                                                                                                                                  Not Found
# 7                                                                                                                      Mississippi, United States of America
# 8                                                                                     Léandre, Le Mont-Bellevue, Sherbrooke, Estrie, Québec, J1H 2B5, Canada
# 9                                                                                                      Iberville Parish, Louisiana, United States of America
# 10                                                                                              Edna, Jackson County, Texas, 77957, United States of America
# 11                                                                                                Paris, Île-de-France, France métropolitaine, 75004, France
# 12    Le Gouvernail, Avenue Charles-De Foucauld, Vieux-Moulin, La Cité-Limoilou, Québec, Québec (Agglomération), Capitale-Nationale, Québec, G1E 6G7, Canada
# 13                                                                                                                       Louisiana, United States of America
# 14                                                                                       Armand, Torre Pellice, Provincia di Torino, Piemonte, 10066, Italia
# 15  Beaudelet, Avenue Henri Beaudelet, La Petite Chauvennerie, Ozoir-la-Ferrière, Torcy, Seine-et-Marne, Île-de-France, France métropolitaine, 77330, France
# 16                                                                                                            Toéni, Sourou, Boucle du Mouhoun, Burkina Faso
# 17                                                                        Grand Isle, Grand Isle Township, Aroostook County, Maine, United States of America
# 18                                                                        Gutenberg, Rüdesheim, Landkreis Bad Kreuznach, Rheinland-Pfalz, 55595, Deutschland
# 19                           U.S., State Highway 55, Sunny Waters, Langlade, Town of Wolf River, Langlade County, Wisconsin, 54462, United States of America
# 20                                                                                                                                                 Not Found
# 21                                                                                The City, 36, Agua Prieta, Municipio de Agua Prieta, Sonora, 84200, México
# 22                Impromptu, Rue de l'Ange, Bergougnan, Bonnabaud, Clermont-Ferrand, Puy-de-Dôme, Auvergne-Rhône-Alpes, France métropolitaine, 63000, France
# 23                                                                                                     Celina, Mercer County, Ohio, United States of America
# 24                                                                                    Labrihe, Condom, Gers, Occitanie, France métropolitaine, 32120, France
# 25                                         Unidad Técnica de Ferrocarriles, Avenida d'Orbigny, Molle, Cochabamba, Kanata, Cercado, Cochabamba, 1830, Bolivia
# 26                                                                                                              Carondelet, San Lorenzo, Esmeraldas, Ecuador
# 27                                                                                             Eskimo, Pfungen, Bezirk Winterthur, Zürich, 8422, Switzerland
# 28                                                                                                                                                 Not Found
# 29                                                                                            Biloxi, Harrison County, Mississippi, United States of America
# 30                                                                                                                                Angostura, Sinaloa, México
# 31                                                                                    Empire, Stanislaus County, California, 95319, United States of America
# 32                                                                 Lourdes, Argelès-Gazost, Hautes-Pyrénées, Occitanie, France métropolitaine, 65100, France
# 33          Acadian, Oak Crest Drive, University Park Apartments, Arbolada Addition, Lafayette, Lafayette Parish, Louisiana, 70502, United States of America
# 34                                                                                          New Orleans, Orleans Parish, Louisiana, United States of America
# 35                                                                                       Carrolton, San Joaquin County, California, United States of America
# 36                                                                                                   City of London, Greater London, England, United Kingdom
# 37                                                                                    Gruyères, District de la Gruyère, Fribourg/Freiburg, 1663, Switzerland
# 38                                                                        Candelabra, Goodluck, Forrest County, Mississippi, 39465, United States of America
# 39                                                                                                                                       Genève, Switzerland
# 40                                                                                                       Victor, Iowa County, Iowa, United States of America
# 41                                                                                        Bandana, Ballard County, Kentucky, 42022, United States of America
# 42                                                                                                                                                 Not Found
# 43                                                                                                                                                 Not Found
# 44                                                                                                                               Mariquita, Tolima, Colombia
# 45                                                                                                            America, Horst aan de Maas, Limburg, Nederland
# 46                                                          Lahonce, Bayonne, Pyrénées-Atlantiques, Nouvelle-Aquitaine, France métropolitaine, 64990, France
# 47                                                                                                                                                 Not Found
# 48                                                                                             Venus, Johnson County, Texas, 76084, United States of America
# 49                                                                                                                                                    France
# 50                                                                                                                                                 Not Found
# 51                                                                                       Janie, Boone County, West Virginia, 25193, United States of America
# 52                                                                                                                                       Magdalena, Colombia
# 53                                                                                                                                             United States
# 54                                                                        Gutenberg, Rüdesheim, Landkreis Bad Kreuznach, Rheinland-Pfalz, 55595, Deutschland
# 55                                                                                                     Direct, Lamar County, Texas, United States of America
# 56                                                                     Indirect?, Pipeline Road, San Bernardino County, California, United States of America
# 57                                                                                          Salt Lake City, Salt Lake County, Utah, United States of America
#
#           lat        lon importance
# 0        22.5       -100   0.839924
# 1     29.9499   -90.0701   0.808026
# 2     37.5726   -85.1551   0.821405
# 3     39.7837   -100.446    1.13569
# 4     40.7127    -74.006    1.01758
# 5   Not Found  Not Found  Not Found
# 6   Not Found  Not Found  Not Found
# 7     32.9716   -89.7348   0.810392
# 8     45.3815   -71.9138      0.075
# 9     30.2121   -91.3134   0.571381
# 10    28.9773   -96.6463   0.568482
# 11    48.8567    2.35146    0.94171
# 12    46.8611   -71.2066      0.101
# 13    30.8704   -92.0071   0.823185
# 14    44.8352    7.19927       0.36
# 15    48.7664    2.69154      0.111
# 16    13.4895   -3.10304   0.420736
# 17    47.3053    -68.152   0.601334
# 18      49.88    7.79917   0.572344
# 19    45.1896   -88.7322      0.201
# 20  Not Found  Not Found  Not Found
# 21    31.3022    -109.55      0.201
# 22    45.7792    3.08097      0.111
# 23    40.5489   -84.5702   0.491776
# 24    43.7714   0.877222   0.729163
# 25   -17.3883   -66.1806      0.101
# 26    1.12611   -78.7622       0.46
# 27    47.5193    8.63715       0.21
# 28  Not Found  Not Found  Not Found
# 29    30.3747   -88.8459   0.634713
# 30    25.1222   -108.151       0.56
# 31    37.6382   -120.902   0.460293
# 32    43.0941 -0.0464975   0.682055
# 33    30.2077    -92.023      0.111
# 34    29.9499   -90.0701   0.808026
# 35    37.7985    -121.07       0.36
# 36    51.5156 -0.0919983   0.686511
# 37    46.5838    7.08267   0.402244
# 38    31.3326   -89.1664        0.2
# 39    46.2018     6.1466   0.690157
# 40    41.7317    -92.298   0.546773
# 41    37.1462   -88.9459   0.366097
# 42  Not Found  Not Found  Not Found
# 43  Not Found  Not Found  Not Found
# 44    5.22711   -74.8983   0.393846
# 45    51.4477    5.96607   0.439261
# 46    43.4832   -1.39025   0.547529
# 47  Not Found  Not Found  Not Found
# 48    32.4335   -97.1025   0.553871
# 49    46.6034    1.88833    1.02333
# 50  Not Found  Not Found  Not Found
# 51    37.9823   -81.5384   0.405576
# 52         10      -74.5       0.65
# 53    39.7837   -100.446    1.13569
# 54      49.88    7.79917   0.562344
# 55    33.8209   -95.8366       0.35
# 56    34.6653   -116.976      0.101
# 57    40.7596   -111.887   0.937243

# %% [markdown]
# ## Making an Interactive Map

# %% [markdown]
# To map our geocoded coordinates, we're going to use the Python library [Folium](https://python-visualization.github.io/folium/). Folium is built on top of the popular JavaScript library [Leaflet](https://leafletjs.com/).

# %%
# !pip install folium

# %%
import folium

# %% [markdown]
# ### Base Map

# %% [markdown]
# First, we need to establish a base map. This is where we'll map our geocoded locations. To do so, we're going to call `folium.Map()`and enter the general latitude/longitude coordinates of the New Orleans area at a particular zoom.
#
# To find latitude/longitude coordintes for a particular location, you can use Google Maps, [as described here](https://support.google.com/maps/answer/18539?co=GENIE.Platform%3DDesktop&hl=en).

# %%
places_map = folium.Map(location=[29.98, -90.01], zoom_start=3)
places_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Add Markers From Pandas Data

# %% [markdown]
# Adding a marker to a map is easy with Folium. We'll simply call `folium.Marker()` at a particular lat/lon, enter some text to display when the marker is clicked on, and then add it to our base map.

# %% [markdown]
# To add markers for every location in our Pandas dataframe, we can make a Python function and `.apply()` it to every row in the dataframe.

# %%
def create_map_markers(row, map_name):
    folium.Marker(location=[row['lat'], row['lon']], popup=row['place']).add_to(map_name)

# %% [markdown]
# Before we apply this function to our dataframe, we're going to drop any locations that were "Not Found" (which would cause `folium.Marker()` to return an error).

# %%
found_place_locations = places_df[places_df['address'] != "Not Found"]

# %%
found_place_locations.apply(create_map_markers, map_name=places_map, axis='columns')
places_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Conclusion

# %% [markdown]
# *Essays will conclude with final insights and possibilities for future work in the area*
